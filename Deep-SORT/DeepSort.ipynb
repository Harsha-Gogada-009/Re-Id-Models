# %%
# !git clone https://github.com/cajmorgan/deep-sort-reid.git
# Out:
# Cloning into 'deep-sort-reid'...
# remote: Enumerating objects: 272, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 272 (delta 52), reused 87 (delta 33), pack-reused 153 (from 1)
# Receiving objects: 100% (272/272), 106.67 MiB | 46.38 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# %%writefile requirements.txt
# absl-py==2.1.0
# annotated-types==0.7.0
# autopep8==2.3.2
# beautifulsoup4==4.13.3
# certifi==2025.1.31
# chardet==5.2.0
# charset-normalizer==3.4.1
# contourpy==1.3.1
# cycler==0.12.1
# Cython==3.0.11
# filelock==3.17.0
# flake8==7.1.1
# fonttools==4.56.0
# fsspec==2025.2.0
# future==1.0.0
# gdown==5.2.0
# grpcio==1.70.0
# h5py==3.12.1
# idna==3.10
# imageio==2.37.0
# isort==4.3.21
# Jinja2==3.1.5
# kiwisolver==1.4.8
# Markdown==3.7
# MarkupSafe==3.0.2
# matplotlib==3.10.0
# mccabe==0.7.0
# mpmath==1.3.0
# networkx==3.4.2
# numpy>=1.20.0
# opencv-python==4.11.0.86
# packaging==24.2
# pandas==2.2.3
# pillow==11.1.0
# platformdirs==4.3.6
# protobuf==5.29.3
# psutil==6.1.1
# py-cpuinfo==9.0.0
# pycodestyle==2.12.1
# pydantic==2.10.6
# pydantic_core==2.27.2
# pyflakes==3.2.0
# pyparsing==3.2.1
# PySocks==1.7.1
# python-dateutil==2.9.0.post0
# pytz==2025.1
# PyYAML==6.0.2
# requests==2.32.3
# scipy==1.15.1
# seaborn==0.13.2
# six==1.17.0
# soupsieve==2.6
# sympy==1.13.1
# tb-nightly==2.19.0a20250209
# tensorboard==2.18.0
# tensorboard-data-server==0.7.2
# tomli==2.2.1
# torch>=2.5.0
# torchvision>=0.20.0
# tqdm==4.67.1
# typing_extensions==4.12.2
# tzdata==2025.1
# ultralytics==8.3.73
# ultralytics-thop==2.0.14
# urllib3==2.3.0
# Werkzeug==3.1.3
# yacs==0.1.8
# yapf==0.43.0
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# !apt-get install tree  # (Optional: only if tree is not installed)
# !tree -a deep-sort-reid
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (424 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# deep-sort-reid
# ├── deep_sort_reid
# │   ├── constants
# │   │   ├── __init__.py
# │   │   └── tracker.py
# │   ├── DeepSortReid.py
# │   ├── enums
# │   │   ├── __init__.py
# │   │   └── tracker.py
# │   ├── __init__.py
# │   ├── metric
# ...

# %%
# !python /content/deep-sort-reid/example.py
# Out:
# video 1/1 (frame 1/375) /content/0711.mp4: 384x640 1 ball, 16 players, 2 referees, 29.4ms
# video 1/1 (frame 2/375) /content/0711.mp4: 384x640 18 players, 2 referees, 29.4ms
# video 1/1 (frame 3/375) /content/0711.mp4: 384x640 1 ball, 16 players, 2 referees, 29.4ms
# video 1/1 (frame 4/375) /content/0711.mp4: 384x640 1 ball, 14 players, 2 referees, 29.4ms
# video 1/1 (frame 5/375) /content/0711.mp4: 384x640 1 ball, 14 players, 2 referees, 29.4ms
# video 1/1 (frame 6/375) /content/0711.mp4: 384x640 16 players, 2 referees, 29.4ms
# video 1/1 (frame 7/375) /content/0711.mp4: 384x640 15 players, 2 referees, 29.4ms
# video 1/1 (frame 8/375) /content/0711.mp4: 384x640 15 players, 1 referee, 29.4ms
# video 1/1 (frame 9/375) /content/0711.mp4: 384x640 1 ball, 16 players, 1 referee, 29.4ms
# video 1/1 (frame 10/375) /content/0711.mp4: 384x640 1 ball, 15 players, 2 referees, 29.4ms
# video 1/1 (frame 11/375) /content/0711.mp4: 384x640 1 ball, 15 players, 2 referees, 29.4ms
# ...
